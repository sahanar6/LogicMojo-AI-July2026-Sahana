# %%
class Account:
    def __init__(self,balance=0):
        self.balance=balance
    def deposit(self,amount):
        self.balance+= amount 
a = Account(100)
a.deposit(50)
print(f"Account A balance: {a.balance}")
b = Account(0)
b.deposit(20)
print("Account B balance:", b.balance)
# Out:
# Account A balance: 150
# Account B balance: 20

# %%
raw = ["10", "7", "x", "3"]
total = 0 
skipped =0  
for value in raw:
    try:
        total += int(value)            
    except ValueError:
        skipped += 1
print("total:", total)
print("skipped:", skipped)
# Out:
# total: 20
# skipped: 1

# %%
import json

data = {"course": "GenAI", "classes": 45}
text = json.dumps(data)
print("as text:", text)
print("updated classes:", json.loads(text) ["classes"]+1)
# Out:
# as text: {"course": "GenAI", "classes": 45}
# updated classes: 46

# %%
class Account:
    def __init__(self,balance):
        self.balance = balance
    def summary(self):
            return f"{self.balance}"

class SavingsAccount(Account):
    def __init__(self,balance,rate):
        super().__init__(balance)
        self.rate = rate
    def summary(self):
        return f"{self.balance} at {self.rate}"
   
for acc in [Account(100), SavingsAccount(200, 0.05)]:
   print(f"{type(acc).__name__}: {acc.summary()}")
# Out:
# Account: 100
# SavingsAccount: 200 at 0.05
