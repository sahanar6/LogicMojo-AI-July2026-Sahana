# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
arr = np.array([2,4,6,8,10])
print("plus 10:", arr+10)
arr1 = np.array([1, 2, 3])
arr2 = np.array([4,5,6])
print("product:", arr1*arr2)
print("mean:", arr.mean())
# Out:
# plus 10: [12 14 16 18 20]
# product: [ 4 10 18]
# mean: 6.0
